# %%
class City():
    def __init__(self, name, lat, lon):
        self.name = name
        self.lat = float(lat)
        self.lon = float(lon)

cities = []
def cityreader(cities=[]):
    import csv
    with open('cities.csv') as c:
        city_generator = csv.reader(c, delimiter=',')
        next(city_generator)
        for row in city_generator:
            cities.append(City(row[0], row[3], row[4]))
        return cities

# %%
cityreader(cities)
# Out:
# [<__main__.City at 0x10d674210>,
#  <__main__.City at 0x10d283f90>,
#  <__main__.City at 0x10d55d650>,
#  <__main__.City at 0x10d674810>,
#  <__main__.City at 0x10d7cd5d0>,
#  <__main__.City at 0x10d674710>,
#  <__main__.City at 0x10d7cd990>,
#  <__main__.City at 0x10d7cd2d0>,
#  <__main__.City at 0x10d605ed0>,
#  <__main__.City at 0x10bdd0a90>,
#  <__main__.City at 0x10d605bd0>,
#  <__main__.City at 0x10d605250>,
#  <__main__.City at 0x10d605310>,
#  <__main__.City at 0x10d605110>,
#  <__main__.City at 0x10d605150>,
#  <__main__.City at 0x10d6059d0>,
#  <__main__.City at 0x10d605750>,
#  <__main__.City at 0x10d65a610>,
#  <__main__.City at 0x10d65a050>,
#  <__main__.City at 0x10d605f90>,
#  <__main__.City at 0x10d65a750>,
#  <__main__.City at 0x10d605f50>,
#  <__main__.City at 0x10d605a50>,
#  <__main__.City at 0x10d605690>,
#  <__main__.City at 0x10d605950>,
#  <__main__.City at 0x10d65f2d0>,
#  <__main__.City at 0x10d65f850>,
#  <__main__.City at 0x10d65fdd0>,
#  <__main__.City at 0x10d65fe50>,
#  <__main__.City at 0x10d65ff50>,
#  <__main__.City at 0x10d65f810>,
#  <__main__.City at 0x10d65f350>,
#  <__main__.City at 0x10d65f710>,
#  <__main__.City at 0x10d65f610>,
#  <__main__.City at 0x10d65fa90>,
#  <__main__.City at 0x10d65f8d0>,
#  <__main__.City at 0x10d65f0d0>,
#  <__main__.City at 0x10d65fd10>,
#  <__main__.City at 0x10d65fc50>,
#  <__main__.City at 0x10d65f150>,
#  <__main__.City at 0x10d65f650>,
#  <__main__.City at 0x10d65f050>,
#  <__main__.City at 0x10d7be210>,
#  <__main__.City at 0x10d7be9d0>,
#  <__main__.City at 0x10d7bea50>,
#  <__main__.City at 0x10d7be0d0>,
#  <__main__.City at 0x10d7be750>,
#  <__main__.City at 0x10d7be350>,
#  <__main__.City at 0x10d7be1d0>,
#  <__main__.City at 0x10d7bef50>,
#  <__main__.City at 0x10d7bee50>,
#  <__main__.City at 0x10d7bec90>,
#  <__main__.City at 0x10bef8190>,
#  <__main__.City at 0x10bef8150>,
#  <__main__.City at 0x10d7be650>,
#  <__main__.City at 0x10d7be890>,
#  <__main__.City at 0x10d7beb90>,
#  <__main__.City at 0x10d7be950>,
#  <__main__.City at 0x10d60e090>,
#  <__main__.City at 0x10d60ead0>]

# %%
# Create a class to hold a city location. Call the class "City". It should have
# fields for name, lat and lon (representing latitude and longitude).
class City():
    def __init__(self, name, lat, lon):
        self.name = name
        self.lat = lat
        self.lon = lon

# We have a collection of US cities with population over 750,000 stored in the
# file "cities.csv". (CSV stands for "comma-separated values".)
#
# In the body of the `cityreader` function, use Python's built-in "csv" module 
# to read this file so that each record is imported into a City instance. Then
# return the list with all the City instances from the function.
# Google "python 3 csv" for references and use your Google-fu for other examples.
#
# Store the instances in the "cities" list, below.
#
# Note that the first line of the CSV is header that describes the fields--this
# should not be loaded into a City object.
class City():
    def __init__(self, name, lat, lon):
        self.name = name
        self.lat = float(lat)
        self.lon = float(lon)

cities = []
def cityreader(cities=[]):
    import csv
    with open('cities.csv') as c:
        city_generator = csv.reader(c, delimiter=',')
        next(city_generator)
        for row in city_generator:
            cities.append(City(row[0], row[3], row[4]))
        return cities            

# Print the list of cities (name, lat, lon), 1 record per line.
for c in cities:
    print(c)

# STRETCH GOAL!
#
# Allow the user to input two points, each specified by latitude and longitude.
# These points form the corners of a lat/lon square. Pass these latitude and 
# longitude values as parameters to the `cityreader_stretch` function, along
# with the `cities` list that holds all the City instances from the `cityreader`
# function. This function should output all the cities that fall within the 
# coordinate square.
#
# Be aware that the user could specify either a lower-left/upper-right pair of
# coordinates, or an upper-left/lower-right pair of coordinates. Hint: normalize
# the input data so that it's always one or the other, then search for cities.
# In the example below, inputting 32, -120 first and then 45, -100 should not
# change the results of what the `cityreader_stretch` function returns.
#
# Example I/O:
#
# Enter lat1,lon1: 45,-100
# Enter lat2,lon2: 32,-120
# Albuquerque: (35.1055,-106.6476)
# Riverside: (33.9382,-117.3949)
# San Diego: (32.8312,-117.1225)
# Los Angeles: (34.114,-118.4068)
# Las Vegas: (36.2288,-115.2603)
# Denver: (39.7621,-104.8759)
# Phoenix: (33.5722,-112.0891)
# Tucson: (32.1558,-110.8777)
# Salt Lake City: (40.7774,-111.9301)

# TODO Get latitude and longitude values from the user

def cityreader_stretch(lat1, lon1, lat2, lon2, cities=[]):
    # within will hold the cities that fall within the specified region
    within = []
    import csv
    with open('cities.csv') as c:
        city_generator = csv.reader(c, delimiter=',')
        next(city_generator)
        for row in city_generator:
            cities.append(City(row[0], row[3], row[4]))
    for city in cities:
        if abs(lat1) < abs(city.lat) < abs(lat2) and abs(lon1) < abs(city.lon) < abs(lon2):
            within.append(city)
        if abs(lat2) < abs(city.lat) < abs(lat1) and abs(lon2) < abs(city.lon) < abs(lon1):
            within.append(city)
        if lat1 < city.lat < lat2 and lon1 < city.lon < lon2:
            within.append(city)
    # TODO Ensure that the lat and lon valuse are all floats
    # Go through each city and check to see if it falls within 
    # the specified coordinates.
    return within

# %%
cities_within = cityreader_stretch(32, -120, 45, -100, cityreader())

# %%
print(len(cities_within))
for city in cities_within:
    print(city.name)
# Out:
# 18
# Albuquerque
# Riverside
# San Diego
# Los Angeles
# Las Vegas
# Denver
# Phoenix
# Tucson
# Salt Lake City
# Albuquerque
# Riverside
# San Diego
# Los Angeles
# Las Vegas
# Denver
# Phoenix
# Tucson
# Salt Lake City
