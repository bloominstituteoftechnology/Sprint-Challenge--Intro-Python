# %%
import pandas as pd

# %%
cd cityreader
# Out:
# /Users/huskeycl/Documents - LSDS Lambda School/LSDS-Computer-Science-CS/Sprint-Challenge--Intro-Python/src/cityreader

# %%
pwd
# Out:
# '/Users/huskeycl/Documents - LSDS Lambda School/LSDS-Computer-Science-CS/Sprint-Challenge--Intro-Python/src/cityreader'

# %%
cities_df = pd.read_csv("cities.csv")
cities_df
# Out:
#               city            state_name            county_name      lat  \
# 0          Seattle            Washington                   King  47.6217
# 1         Richmond              Virginia        Richmond (city)  37.5294
# 2   Virginia Beach              Virginia  Virginia Beach (city)  36.7335
# 3       Washington  District of Columbia   District of Columbia  38.9047
# 4        Milwaukee             Wisconsin              Milwaukee  43.0640
# 5          Orlando               Florida                 Orange  28.4801
# 6            Miami               Florida             Miami-Dade  25.7840
# 7            Tampa               Florida           Hillsborough  27.9937
# 8     Jacksonville               Florida                  Duval  30.3322
# 9      Albuquerque            New Mexico             Bernalillo  35.1055
# 10      Fort Worth                 Texas                Tarrant  32.7813
# 11         McAllen                 Texas                Hidalgo  26.2203
# ...

# %%
cities_df.shape
# Out:
# (60, 9)
